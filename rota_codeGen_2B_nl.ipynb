# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-2B-nl")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-2B-nl")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/995 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/11.3G [00:00<?, ?B/s]

# %%
text = "function to calculate square root of given number"
input_ids = tokenizer(text, return_tensors="pt").input_ids
generated_ids = model.generate(input_ids, max_length=128)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# function to calculate square root of given number
#
# I have a function that calculates the square root of a number. I want to write a function that takes a number and returns the square root of that number.
# I have tried the following:
# def sqrt(x):
#     return x**0.5
#
# But I get the following error:
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and'str'
#
# A:
#
# You can use the built-in function math.sqrt:
# >>> math.sqrt(5)
# 2

# %%
text = "Write a Python function named factorial that calculates the factorial of a given number using a recursive approach. The function should take a single integer argument and return the factorial of that number. Ensure to handle the base case where the factorial of 0 is 1, and include comments explaining each step of the code."
input_ids = tokenizer(text, return_tensors="pt").input_ids
generated_ids = model.generate(input_ids, max_length=256)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Write a Python function named factorial that calculates the factorial of a given number using a recursive approach. The function should take a single integer argument and return the factorial of that number. Ensure to handle the base case where the factorial of 0 is 1, and include comments explaining each step of the code.
#
# I have a function that takes a list of numbers and returns the factorial of each number in the list. I am trying to write a function that takes a single number and returns the factorial of that number. I am not sure how to do this. I have tried to use recursion but I am not sure how to do it.
#
# I have a function that takes a list of numbers and returns the factorial of each number in the list. I am trying to write a function that takes a single number and returns the factorial of that number. I am not sure how to do this. I have tried to use recursion but I am not sure how to do it.
#
# I have a function that takes a list of numbers and returns the factorial of each number in the list. I am trying to write a function that takes a single number and returns the factorial of that number. I am not sure how to

# %%
text = '''The following Python function calculates the sum of all elements in a list. Add functionality to this code so that it also calculates and returns the product of all elements in the list. Ensure to modify the function signature and update the return statement to return both the sum and the product.
def calculate_sum(numbers):
    total = 0
    for number in numbers:
        total += number
    return total
'''
input_ids = tokenizer(text, return_tensors="pt").input_ids
generated_ids = model.generate(input_ids, max_length=256)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The following Python function calculates the sum of all elements in a list. Add functionality to this code so that it also calculates and returns the product of all elements in the list. Ensure to modify the function signature and update the return statement to return both the sum and the product.
# def calculate_sum(numbers):
#     total = 0
#     for number in numbers:
#         total += number
#     return total
#
# def calculate_product(numbers):
#     total = 1
#     for number in numbers:
#         total *= number
#     return total
#
# numbers = [1, 2, 3, 4, 5]
#
# print(calculate_sum(numbers))
# print(calculate_product(numbers))
#
# A:
#
# You can use a generator expression to calculate the product of all elements in a list:
# def calculate_product(numbers):
#     return sum(n * n for n in numbers)
#
# numbers = [1, 2, 3, 4, 5]
# print(calculate_product(numbers
