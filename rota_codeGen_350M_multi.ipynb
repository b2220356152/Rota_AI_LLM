# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-multi")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-multi")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# ...

# %%
text = "function to calculate square root of given number"
input_ids = tokenizer(text, return_tensors="pt").input_ids
generated_ids = model.generate(input_ids, max_length=128)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# function to calculate square root of given number
#         """
#         return math.sqrt(self.value)
#
#     def __repr__(self):
#         return '{}({})'.format(self.__class__.__name__, self.value)
#
#     def __str__(self):
#         return str(self.value)
#
#     def __eq__(self, other):
#         return self.value == other.value
#
#     def __ne__(self, other):
#         return self.value!= other.value
#
#     def __lt__(self, other

# %%
text = "Write a Python function named factorial that calculates the factorial of a given number using a recursive approach. The function should take a single integer argument and return the factorial of that number. Ensure to handle the base case where the factorial of 0 is 1, and include comments explaining each step of the code."
input_ids = tokenizer(text, return_tensors="pt").input_ids
generated_ids = model.generate(input_ids, max_length=256)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Write a Python function named factorial that calculates the factorial of a given number using a recursive approach. The function should take a single integer argument and return the factorial of that number. Ensure to handle the base case where the factorial of 0 is 1, and include comments explaining each step of the code.
#
# # Note:
# # 1. The function should be written in Python.
# # 2. The function should be written in Python.
# # 3. The function should be written in Python.
# # 4. The function should be written in Python.
# # 5. The function should be written in Python.
# # 6. The function should be written in Python.
# # 7. The function should be written in Python.
# # 8. The function should be written in Python.
# ...

# %%
text = '''The following Python function calculates the sum of all elements in a list. Add functionality to this code so that it also calculates and returns the product of all elements in the list. Ensure to modify the function signature and update the return statement to return both the sum and the product.
def calculate_sum(numbers):
    total = 0
    for number in numbers:
        total += number
    return total
'''
input_ids = tokenizer(text, return_tensors="pt").input_ids
generated_ids = model.generate(input_ids, max_length=256)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The following Python function calculates the sum of all elements in a list. Add functionality to this code so that it also calculates and returns the product of all elements in the list. Ensure to modify the function signature and update the return statement to return both the sum and the product.
# def calculate_sum(numbers):
#     total = 0
#     for number in numbers:
#         total += number
#     return total
#
# # This function calculates the product of all elements in a list. Add functionality to this code so that it also calculates and returns the product of all elements in the list. Ensure to modify the function signature and update the return statement to return both the sum and the product.
# ...
